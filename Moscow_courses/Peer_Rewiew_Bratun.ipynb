# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('D:\Downloads\weights_heights.csv', index_col='Index')

# %%
data.head()
# Out:
#          Height    Weight
# Index
# 1      65.78331  112.9925
# 2      71.51521  136.4873
# 3      69.39874  153.0269
# 4      68.21660  142.3354
# 5      67.78781  144.2971

# %%
data.shape
# Out:
# (25000, 2)

# %%
data.plot(x='Weight',y='Height', kind='hist', 
           color='red',  title='Height (inch.) distribution')

# %%
def make_bmi(height_inch, weight_pound):
    METER_TO_INCH, KILO_TO_POUND = 39.37, 2.20462
    return (weight_pound / KILO_TO_POUND) / \
           (height_inch / METER_TO_INCH) ** 2

# %%
data['BMI'] = data.apply(lambda row: make_bmi(row['Height'], 
                                              row['Weight']), axis=1)

# %%
sns.pairplot(data,palette='husl',diag_kind="kde",kind="reg")

# %%
def weight_category(weight):
    if weight < 120:
        return 1
    elif weight >= 150:
        return 3
    else: return 2
    # Ваш код здесь

data['weight_cat'] = data['Weight'].apply(weight_category)
# Ваш код здесь

# %%
data.plot(x='Weight',y='Height', kind='scatter')
